# %% [markdown]
# #### **DB Creation and setup**

# %% [markdown]
# - Created a db named **BBMS** with user hemendra
# - Created a schema named raw
#
#
# ---------

# %% [markdown]
# #### **Raw Tables Creation**

# %% [markdown]
# Created 12 **raw tables** and inserted source data
#
# - `raw.blood_inventory`
#
# - `raw.blood_tests`
#
# - `raw.blood_type_compatibility`
#
# - `raw.donations`
#
# - `raw.donors`
#
# - `raw.donor_history`
#
# - `raw.hospitals`
#
# - `raw.recipients`
#
# - `raw.technicians`
#
# - `raw.technician_tasks`
#
# - `raw.tasks`
#
# ----------
