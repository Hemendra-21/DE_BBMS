# %% [markdown]
# #### **1) Folder Creation**

# %%
mkdir DE_Project
cd DE_Project

# %% [markdown]
# #### **2) Create Virtual Environment**

# %%
python3 -m venv venv

# %% [markdown]
# #### **Activate venv**

# %%
source venv/bin/activate

# %% [markdown]
# #### **3) Install dbt with Postgres Adapter**

# %%
pip install --upgrade pip
pip install dbt-postgres

# %% [markdown]
# **Verify**

# %%
dbt --version

# %% [markdown]
# **You should see something like this:**

# %%
Core:
  - installed: 1.11.4
  - latest:    1.11.4 - Up to date!

Plugins:
  - postgres: 1.10.0 - Up to date!

# %% [markdown]
# #### **4) Create master folder**

# %%
mkdir master
cd master

# %% [markdown]
# #### **5) Initialize dbt Project**

# %%
dbt init blood_bank_management_system

# %% [markdown]
# It will ask:
#
# - Adapter → choose `postgres`
#
# - Host → localhost
#
# - Port → 5432
#
# - User → hemendra
#
# - Password → your postgres password
#
# - Database → BBMS
#
# - Schema → analytics

# %% [markdown]
# #### **6) Test Connection**

# %%
cd blood_bank_management_system
dbt debug

# %% [markdown]
# **If everything is correct → ✅ connection successful.**

# %% [markdown]
# #### **🎯 Final Structure**

# %% [markdown]
# DE_Project
# ├── venv
# └── master
#     └── blood_bank_management_system
#     └── DDL's
#     └── Miscellaneous

# %% [markdown]
# #### **Steps to open profiles.yml file**

# %%
code ~/.dbt/profiles.yml
